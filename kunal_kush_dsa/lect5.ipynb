# %% [markdown]
# ![image.png](attachment:image.png)
# - variables are stored in Stack
# - the value of variables are stored in Heap(memory)
# - a is a variable stored in stack memory, pointing towards the value in heap memory
