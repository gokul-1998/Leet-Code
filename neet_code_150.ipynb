# %% [markdown]
# 1) https://neetcode.io/problems/is-anagram

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2) https://neetcode.io/problems/two-integer-sum
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3) https://neetcode.io/problems/anagram-groups
#
# ![image.png](attachment:image.png)
